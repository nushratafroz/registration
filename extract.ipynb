# %%
import pydicom
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image 
from pathlib import Path

# %%
# Specify the directory using Path
directory_path = Path(r'C:\Users\roza\Desktop\CSS\CSS 2\2-cube-sag')

# Get a list of all files in the directory
file_list = list(directory_path.iterdir())

# Filter for specific file types (e.g., DICOM files)
dcm_files = [file for file in file_list if file.suffix == '.dcm']
#print(dcm_files)

# Loop through the list of DICOM files and read/display their contents
counter = 1
for dcm_file in dcm_files:
    counter = counter + 1
    dataset = pydicom.dcmread(dcm_file)
    print(dataset)
    if counter == 0
    break
    
#     print(f'File Name: {dcm_file.name}')
#     print('DICOM Information:')
#     print(dataset)
#     print('\n')
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 240
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113619.2.322.2807.8093571.13860.1580987292.707
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Lossless, Non-Hierarchical, First-Order Prediction (Process 14 [Selection Value 1])
# (0002, 0012) Implementation Class UID            UI: 1.2.392.200045.4079.1
# (0002, 0013) Implementation Version Name         SH: ''
# (0002, 0016) Source Application Entity Title     AE: 'SQSTS01'
# (0002, 0100) Private Information Creator UID     UI: 1.2.392.200045.4079.1
# (0002, 0102) Private Information                 OB: b'001\x00'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# ...

# %%
    
# # Loop through the list of DICOM files and display the images using matplotlib
counter = -1
for dcm_file in dcm_files:
    counter = counter + 1
    dataset = pydicom.dcmread(dcm_file)

    # Access the pixel data
    pixel_data = dataset.PixelData
    
    

    # Print the pixel data
    print("Pixel Data:")
    print(pixel_data)
    if counter == 1:
        break

    
#     # Display the image using matplotlib
#     plt.imshow(pixel_data, cmap=plt.cm.gray)  
#     plt.title(f'DICOM Image: {dcm_file.name}')
#     plt.show()
# Out:
# Pixel Data:
# ...

# %%
counter = -1
for dcm_file in dcm_files:
    counter = counter + 1
    dataset = pydicom.dcmread(dcm_file)

    # Access and convert the pixel data to a NumPy array
    pixel_data = dataset.pixel_array

    # Print some information about the pixel data
    print(f"File {counter}: {dcm_file}")
    print(f"Pixel Data Shape: {pixel_data.shape}")
    print(f"Pixel Data Type: {pixel_data.dtype}")

    if counter == 0:
        break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[73], line 7
#       4 dataset = pydicom.dcmread(dcm_file)
#       6 # Access and convert the pixel data to a NumPy array
# ----> 7 pixel_data = dataset.pixel_array
#       9 # Print some information about the pixel data
#      10 print(f"File {counter}: {dcm_file}")
#
# File ~\anaconda3\envs\css\Lib\site-packages\pydicom\dataset.py:1955, in Dataset.pixel_array(self)
#    1940 @property
#    1941 def pixel_array(self) -> "numpy.ndarray":
#    1942     """Return the pixel data as a :class:`numpy.ndarray`.
#    1943
#    1944     .. versionchanged:: 1.4
#    (...)
#    1953         :class:`numpy.ndarray`.
#    1954     """
# -> 1955     self.convert_pixel_data()
#    1956     return cast("numpy.ndarray", self._pixel_array)
#
# ...
